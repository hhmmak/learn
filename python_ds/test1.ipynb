# %%
import numpy as np

# %%
s_dyna = [0, 1, 2, 1, 0]
a_dyna = [1, 0, 1, 1, 0]
t = np.array([
    # For state 0
    [
        [0.2, 0.5, 0.3],  # Action 0
        [0.1, 0.7, 0.2]   # Action 1
    ],
    # For state 1
    [
        [0.6, 0.3, 0.1],  # Action 0
        [0.4, 0.4, 0.2]   # Action 1
    ],
    # For state 2
    [
        [0.3, 0.2, 0.5],  # Action 0
        [0.5, 0.3, 0.2]   # Action 1
    ]
])

# %%
t[s_dyna, a_dyna]
# Out:
# array([[0.1, 0.7, 0.2],
#        [0.6, 0.3, 0.1],
#        [0.5, 0.3, 0.2],
#        [0.4, 0.4, 0.2],
#        [0.2, 0.5, 0.3]])

# %%
s_prime_dyna = t[s_dyna, a_dyna].argmax(axis=1)
s_prime_dyna
# Out:
# array([1, 0, 0, 0, 1])
